# %% [markdown]
# # Imports & Setup

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import DataLoader

from torchvision.datasets import MNIST
from torchvision import transforms

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Check Cuda Availability

# %%
cuda_available = torch.cuda.is_available()
print(f'CUDA Available: {cuda_available}')
if cuda_available:
    print('CUDA device:', torch.cuda.get_device_name(0))
# Out:
# CUDA Available: True
# CUDA device: NVIDIA A100-SXM4-80GB

# %% [markdown]
# # Data Loading & Preprocessing
# ## Dataset Transforms

# %%
transform = transforms.Compose([
    transforms.ToTensor(),                                 # Transform images to tensors
    lambda image: image.view(image.size(1), image.size(2)) # Remove color channel dimension, since we only have black and white
])

# %% [markdown]
# ## Getting the data, transforming, and loading it

# %%
# Get and load data
mnist_train = MNIST(root="./", train=True, download=True, transform=transform)
mnist_test = MNIST(root="./", train=False, download=True, transform=transform)

# DataLoaders
train_loader = DataLoader(mnist_train, batch_size=10000, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size=10000, shuffle=True)

# %% [markdown]
# ## Example Input: Raw Data

# %%
for images, labels in test_loader:
    sample_image = images[0]
    sample_label = labels[0]
    break

print('type:', type(sample_image))
print('shape:', sample_image.shape)
print('raw data:', sample_image)
# Out:
# type: <class 'torch.Tensor'>
# shape: torch.Size([28, 28])
# raw data: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0549, 0.2784, 0.7451, 0.9294, 0.5882, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0392, 0.7255, 0.9961, 0.9961, 0.9961, 0.9922, 0.4667, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.4784, 0.9216, 0.3255, 0.3843, 0.5647, 0.9961, 0.6941, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.4275, 0.1686, 0.0000, 0.0000, 0.4196, 0.9961, 0.6941, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.5647, 0.9961, 0.6588, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.5647, 0.9961, 0.5882, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.6471, 0.9843, 0.2667, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.2706, 0.9882, 0.9412, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.4471, 0.9961, 0.6745, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.6980, 0.9608, 0.4588, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0157, 0.4039, 0.9412, 0.8196, 0.0353, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.4667, 0.9961, 0.9961, 0.9961, 0.8588, 0.6784, 0.4745, 0.0627,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.3451, 0.9059, 0.9961, 0.9961, 0.9961, 0.9961, 0.9961, 0.6235,
#          0.0588, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0941, 0.2078, 0.2078, 0.2275, 0.8510, 0.9961, 0.9961,
#          0.3373, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3059, 0.9961, 0.9961,
#          0.3373, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3059, 0.9961, 0.9961,
#          0.3373, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.4627, 0.9961, 0.9765,
#          0.2039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0510, 0.4510, 0.9961, 0.9529, 0.2863,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0431, 0.4431, 0.9961, 0.9961, 0.3020, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.2039, 0.8353, 0.9961, 0.9765, 0.5059, 0.0196, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000]])

# %% [markdown]
# ## Example Input: Visualization

# %%
plt.imshow(sample_image, cmap='gray')

print('sample label:', sample_label) # Label tensor
plt.show()
# Out:
# sample label: tensor(3)

# %% [markdown]
# ## Example Input: Reshaping Data

# %%
print('original shape:', sample_image.shape)
print('reshaped using `view`:', sample_image.view(sample_image.size(0)*sample_image.size(1)).shape)
print('reshaped using `reshape`:', sample_image.reshape(sample_image.size(0)*sample_image.size(1)).shape)
print('reshaped using `flatten`:', sample_image.flatten().shape)
# Out:
# original shape: torch.Size([28, 28])
# reshaped using `view`: torch.Size([784])
# reshaped using `reshape`: torch.Size([784])
# reshaped using `flatten`: torch.Size([784])

# %% [markdown]
# # Neural Network Model

# %%
class Model(nn.Module):
    # Model initialization
    def __init__(self):
        super(Model, self).__init__()

        # Hidden layers
        self.hidden1 = nn.Linear(28*28, 100)
        self.hidden2 = nn.Linear(100, 100)
        self.hidden3 = nn.Linear(100, 100)

        # Output layer
        self.out = nn.Linear(100, 10)

        # Activation functions
        self.relu = nn.ReLU()            # ReLU activation function used on hidden layers
        self.softmax = nn.Softmax(dim=1) # Softmax activation function used on output layer; All values in [0,1] and must sum to 1
        
    # Model operation
    def forward(self, x):
        h1 = self.relu(self.hidden1(x))   # hidden layer 1, ReLU activation
        h2 = self.relu(self.hidden2(h1))  # hidden layer 2, ReLU activation
        h3 = self.relu(self.hidden3(h2))  # hidden layer 3, ReLU activation
        return self.softmax(self.out(h3)) # output layer, Softmax activation

# %% [markdown]
# ## Model Initialization

# %%
model = Model()
if cuda_available:
    model.cuda()

print(model)
# Out:
# Model(
#   (hidden1): Linear(in_features=784, out_features=100, bias=True)
#   (hidden2): Linear(in_features=100, out_features=100, bias=True)
#   (hidden3): Linear(in_features=100, out_features=100, bias=True)
#   (out): Linear(in_features=100, out_features=10, bias=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# ## Training Protocol Initialization

# %%
counts = np.unique(mnist_train.targets, return_counts=True)[1] # get number of occurrences of each label
weights = torch.from_numpy(np.max(counts)/counts).float()      # compute relative weights for each label

if cuda_available:
    weights = weights.cuda()
    
print('label counts:', counts)
print('class weights:', weights)
# Out:
# label counts: [5923 6742 5958 6131 5842 5421 5918 6265 5851 5949]
# class weights: tensor([1.1383, 1.0000, 1.1316, 1.0997, 1.1541, 1.2437, 1.1392, 1.0761, 1.1523,
#         1.1333], device='cuda:0')

# %%
criterion = nn.CrossEntropyLoss(weight=weights)       # Loss function
optim = torch.optim.Adam(model.parameters(), lr=1e-3) # Optimizer

# Learning Rate scheduler (OPTIONAL)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optim, factor=0.1, patience=5, verbose=True)

# %% [markdown]
# # Model Training
# ## Defining training function

# %%
# Run a single epoch
def run_epoch(train):
    # Set model mode and desired dataloader
    if train:
        model.train()
        loader = train_loader
    else:
        model.eval()
        loader = test_loader

    # LOGGING
    total_loss = 0.                # Total epoch loss
    confusion = np.zeros((10, 10)) # Used for tracking accuracy (10 because of 10 labels)

    # Fit batches
    for x, y in loader:
        if cuda_available: # Move tensors over to cuda if present
            x = x.cuda()
            y = y.cuda()

        # Data in the loader is 28x28, but our model expects a flattened tensor
        # This would normally be one of the dataset transforms. Done here for demonstration
        x = x.flatten(start_dim=1, end_dim=2)

        # Put data through model, get predictions. This calls the forward() function!
        predictions = model(x)

        # Calculate loss (how wrong our predictions are)
        loss = criterion(predictions, y)

        if train:
            optim.zero_grad() # Reset gradients
            loss.backward()   # Calculate new gradients
            optim.step()      # Run optimizer & update weights and biases

        # LOGGING
        total_loss += loss.item() * predictions.size(0)
        confusion += confusion_matrix(y.cpu(), predictions.argmax(dim=1).cpu(), labels=range(10))

    if not train:
        scheduler.step(total_loss) # Run learning rate scheduler on

    return total_loss / len(loader.dataset), \
           confusion.diagonal().sum() / confusion.sum(), \
           (confusion.diagonal() / confusion.sum(axis=1)).mean()

# %% [markdown]
# ## Training Variables

# %%
epochs = 50 # Epochs to train for
print_frequency = 5 # Frequency to print results

# Loss during training
train_losses = []
test_losses = []

# Accuracy during training
train_accuracies = []
test_accuracies = []

# Balanced accuracy during training
train_balanced_accuracies = []
test_balanced_accuracies = []

# %% [markdown]
# ## THE TRAINING LOOP!

# %%
for e in range(epochs):
    train_loss, train_accuracy, train_balanced_accuracy = run_epoch(True) # Train model
    test_loss, test_accuracy, test_balanced_accuracy = run_epoch(False)   # Test model

    # Performance tracking
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)
    train_balanced_accuracies.append(train_balanced_accuracy)
    test_balanced_accuracies.append(test_balanced_accuracy)

    if (e+1) % print_frequency == 0:
        epoch_counter = f'Epoch: {" " * (len(str(epochs)) - len(str(e + 1)))}{e + 1}/{epochs}'
        print('----------------------------------------------------------------------------------------------------')
        print(f'{epoch_counter} | Train Loss: {train_loss:.4f} | Train Accuracy: {train_accuracy:.4f} | Train Balanced Accuracy: {train_balanced_accuracy:.4f}')
        print(f'{" " * len(epoch_counter)} |  Test Loss: {test_loss:.4f} |  Test Accuracy: {test_accuracy:.4f} |  Test Balanced Accuracy: {test_balanced_accuracy:.4f}')

    scheduler.step(test_loss)

print('----------------------------------------------------------------------------------------------------')
# Out:
# ----------------------------------------------------------------------------------------------------
# Epoch:  5/50 | Train Loss: 1.9955 | Train Accuracy: 0.5610 | Train Balanced Accuracy: 0.5578
#              |  Test Loss: 1.9216 |  Test Accuracy: 0.6660 |  Test Balanced Accuracy: 0.6619
# ----------------------------------------------------------------------------------------------------
# Epoch: 10/50 | Train Loss: 1.6533 | Train Accuracy: 0.8398 | Train Balanced Accuracy: 0.8366
#              |  Test Loss: 1.6345 |  Test Accuracy: 0.8542 |  Test Balanced Accuracy: 0.8507
# ----------------------------------------------------------------------------------------------------
# Epoch: 15/50 | Train Loss: 1.5808 | Train Accuracy: 0.8945 | Train Balanced Accuracy: 0.8929
#              |  Test Loss: 1.5753 |  Test Accuracy: 0.8978 |  Test Balanced Accuracy: 0.8961
# ----------------------------------------------------------------------------------------------------
# Epoch: 20/50 | Train Loss: 1.5585 | Train Accuracy: 0.9122 | Train Balanced Accuracy: 0.9110
#              |  Test Loss: 1.5577 |  Test Accuracy: 0.9120 |  Test Balanced Accuracy: 0.9108
# ----------------------------------------------------------------------------------------------------
# Epoch: 25/50 | Train Loss: 1.5456 | Train Accuracy: 0.9240 | Train Balanced Accuracy: 0.9231
#              |  Test Loss: 1.5462 |  Test Accuracy: 0.9209 |  Test Balanced Accuracy: 0.9196
# ----------------------------------------------------------------------------------------------------
# Epoch: 30/50 | Train Loss: 1.5366 | Train Accuracy: 0.9319 | Train Balanced Accuracy: 0.9310
#              |  Test Loss: 1.5386 |  Test Accuracy: 0.9290 |  Test Balanced Accuracy: 0.9280
# ----------------------------------------------------------------------------------------------------
# Epoch: 35/50 | Train Loss: 1.5293 | Train Accuracy: 0.9383 | Train Balanced Accuracy: 0.9376
#              |  Test Loss: 1.5327 |  Test Accuracy: 0.9337 |  Test Balanced Accuracy: 0.9328
# ----------------------------------------------------------------------------------------------------
# Epoch: 40/50 | Train Loss: 1.5238 | Train Accuracy: 0.9434 | Train Balanced Accuracy: 0.9428
#              |  Test Loss: 1.5283 |  Test Accuracy: 0.9382 |  Test Balanced Accuracy: 0.9374
# ----------------------------------------------------------------------------------------------------
# Epoch: 45/50 | Train Loss: 1.5181 | Train Accuracy: 0.9484 | Train Balanced Accuracy: 0.9478
#              |  Test Loss: 1.5234 |  Test Accuracy: 0.9417 |  Test Balanced Accuracy: 0.9408
# ----------------------------------------------------------------------------------------------------
# Epoch: 50/50 | Train Loss: 1.5136 | Train Accuracy: 0.9524 | Train Balanced Accuracy: 0.9519
#              |  Test Loss: 1.5201 |  Test Accuracy: 0.9440 |  Test Balanced Accuracy: 0.9433
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Prediction Performance

# %%
# All truths and predictions on the test set
test_truths = []
test_preds = []

# Iterate over the test set
for x, y in test_loader:
    if cuda_available:
        x = x.cuda()
        y = y.cuda()

    x = x.flatten(start_dim=1, end_dim=2)
    predictions = model(x)

    # Store truths and predictions from this batch
    test_truths.extend(y.cpu().numpy())
    test_preds.extend(predictions.argmax(dim=1).cpu().numpy())

# Generate and display confusion matrices

fig, axs = plt.subplots(1,2,figsize=(15,7))
cm = confusion_matrix(test_truths, test_preds)

ConfusionMatrixDisplay(cm).plot(ax=axs[0], cmap='Reds')
axs[0].set_title('Raw')

ConfusionMatrixDisplay((cm/cm.sum(axis=1)).round(decimals=2)).plot(ax=axs[1], cmap='Reds')
axs[1].set_title('Proportional')

fig.suptitle('Test Confusion Matrices')

fig.show()

# %% [markdown]
# # Training plots

# %%
fig, axs = plt.subplots(2,2,figsize=(15,10))

# Loss
axs[0,0].plot(train_losses, label='Training')
axs[0,0].plot(test_losses, label='Test')
axs[0,0].legend()
axs[0,0].set_title(f'Model Loss ({criterion.__class__.__name__})')
axs[0,0].set_xlabel('Epoch')
axs[0,0].set_ylabel('Loss')

# Accuracy
axs[0,1].plot(train_accuracies, label='Training')
axs[0,1].plot(test_accuracies, label='Test')
axs[0,1].legend()
axs[0,1].set_title('Accuracy')
axs[0,1].set_xlabel('Epoch')
axs[0,1].set_ylabel('Loss')

# Balanced Accuracy
axs[1,1].plot(train_balanced_accuracies, label='Training')
axs[1,1].plot(test_balanced_accuracies, label='Test')
axs[1,1].legend()
axs[1,1].set_title('Balanced Accuracy')
axs[1,1].set_xlabel('Epoch')
axs[1,1].set_ylabel('Balanced Accuracy')

fig.delaxes(axs[1,0])

plt.show()
